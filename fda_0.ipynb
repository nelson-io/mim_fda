# %% [markdown]
# <a href="https://colab.research.google.com/github/nelson-io/mim_fda/blob/main/fda_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   Funciones y pasaje de parámetros

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.1.a

# %%
def sqroot(n):
  x = int(n ** (1/2))
  return x

print(sqroot(10))
# Out:
# 3

# %% [markdown]
# 1.1.b

# %%
def sqroot_2(n,m):
  x1 = int(n ** (1/2))
  x2 = int(m ** (1/2))
  return [x1,x2]

print(sqroot_2(10,20))
# Out:
# [3, 4]

# %% [markdown]
# 1.1.c

# %%
def sqroot_n(*args):
  x = [int(arg ** (1/2)) for arg in args]
  return x

print(sqroot_n(1,2,3,10,20,30))
# Out:
# [1, 1, 1, 3, 4, 5]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def prod(n,m): 
  total = 0
  counter = 0
  while counter < m:
    total += n
    counter += 1
  return total

print(prod(10,5))
# Out:
# 50

# %%
def pot(m,n):
    if n==0:
        return 1
          
    answer = m
    increment= m
      
    for i in range(1,n):
        for j in range(1,m):
            answer+=increment
        increment=answer
    return answer
  

print(pot(5,3))
# Out:
# 125

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def product_n(*args):
  x = 1
  for i in args:
    x *= i
  return x
print(product_n(5,5,5))
# Out:
# 125

# %%
def factorial(n):
  x = range(1,n+1)
  out = product_n(*x)
  return out

print(factorial(4))
# Out:
# 24

# %%
def combin(n,k):
  if k > n:
    return None
  else:
    x = factorial(n)/(factorial(k)*factorial(n-k))
    return x

print(combin(5,10))
print(combin(10,2))
# Out:
# None
# 45.0

# %%
def princombin(n):
  for i in range(0,n+1):
    print(combin(n, i))


princombin(10)
# Out:
# 1.0
# 10.0
# 45.0
# 120.0
# 210.0
# 252.0
# 210.0
# 120.0
# 45.0
# 10.0
# 1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def prinline(n):
  for i in range(n):
    print('*', end = '')

prinline(10)
# Out:
# **********
